# %%
from quantum_multiplier import *
import time

# %%
#Select integers to multiply:
a = 40
b = 41

start = time.time()
qc, soln = quantum_multiplier(a, 
                              b, 
                              display_circuit = True, 
                              display_counts = True)
end = time.time()

print("Product = ", soln)
print("Time Taken = ", round(end - start, 2), "seconds")
# Out:
# Product =  1640
# Time Taken =  7.62 seconds
